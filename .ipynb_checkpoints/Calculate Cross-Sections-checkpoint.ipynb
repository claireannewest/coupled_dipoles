# %%
from coupled_dipole_model import DipoleParameters
from coupled_dipole_model import CalculateCrossSections
import numpy as np
import matplotlib.pyplot as plt
hbar_eVs = 6.58212E-16 # Planck's constant [eV*s]

def plot_analytics(which, drive,label):
    """This function plots the individual particle and total cross-sections.
    
    which -- which observable to plot (takes 'ext', 'sca', or 'abs')
    drive -- polarization of light (e.g. x polarized = np.array([1, 0, 0]) )
    """
    w = np.arange(.5,2.48,.005)/hbar_eVs
    Pext = np.zeros((num, len(w)))
    Psca = np.zeros((num, len(w)))
    Pabs = np.zeros((num, len(w)))
    for i in range(0,len(w)):
        Pext[:,i], Psca[:,i], Pabs[:,i] = calc_dips.cross_sects(w=w[i], drive=drive)
    if which == 'ext': P = Pext
    if which == 'sca': P = Psca
    if which == 'abs': P = Pabs
    for i in range(0, num):
        plt.plot(w*hbar_eVs, P[i,:], label=str('particle ')+str(i+1))
    plt.plot(w*hbar_eVs, np.sum(P, axis=0), '--',label='total')
    idx = np.where(np.sum(P, axis=0) == max(np.sum(P, axis=0)))

# %% [markdown]
# ## Example for a rotated prolate spheroid monomer

# %%
num = 1 # number of particles 
def make_mono_input(N, shortaxis, longaxis, angle):
    def_centers = np.zeros((N, 3)) # center of prolate spheroid
    def_orient = np.zeros(N) # angle between z axis, and long axis spheroid
    def_all_radii = np.zeros((N, 2)) # radii of spheroid, (long, short)
    def_orient[0] = angle
    def_all_radii[0, :] = np.array([longaxis, shortaxis])*1.E-7
    return def_centers, def_orient, def_all_radii

def_centers, def_orients, def_all_radii = make_mono_input(N=num, 
                                                     shortaxis=10, # nm
                                                     longaxis=90, # nm
                                                     angle= 0.0# 30*(np.pi/180) # radian
                                                    )

calc_dips = CalculateCrossSections(centers=def_centers, 
                                   orient=def_orients,
                                   all_radii=def_all_radii,
                                   num=num,
                                   n=1.0, 
                                   wp=8.959/hbar_eVs, 
                                   eps_inf=9.695, 
                                   gam_drude=0.073/hbar_eVs
                                  )


plot_analytics(which='abs', drive=np.array([0, 0, 1]),label='long')
# plot_analytics(which='abs', drive=np.array([0, 1, 0]),label='short')


def plot_simulation(filename, labelname, linetype):
    data = np.loadtxt(filename,skiprows=1)
    energy = data[:,0]
    ext_cross = data[:,1]
    abs_cross = data[:,2]
    sca_cross = data[:,3]
    plt.plot(energy, abs_cross, linetype, label=labelname)


name = str('../check_with_simulation/simulated_spectra/single_ellipsoid/Spectrum_bemret_10_10_90_drude_1.0')
plot_simulation(filename=name, linetype='', labelname='sim')


# plt.xlim([1.5, 3.0])
# plt.xlabel('Energy [eV]')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.ylabel('Abs. Cross-section [$\mu$m$^2$]')
plt.tight_layout()
plt.legend(frameon=False,loc='upper left')
plt.show()

# %% [markdown]
# ## Inputs for a Dimer

# %%
num = 2
def make_dimer_input(N, shortaxis1, shortaxis2, longaxis1, longaxis2, angle1, angle2, gapy, gapz):
    if gapz == 0: whichgap = 'y'; gaplen=gapy
    if gapy == 0: whichgap = 'z'; gaplen=gapz

    def_centers = np.zeros((N, 3))
    def_orient = np.zeros(N)
    def_all_radii = np.zeros((N, 2))

    if whichgap == 'z':
        def_centers[0,:] = np.array([ 0, 0, -gapz/2 ])*1.E-7
        def_centers[1,:] = np.array([ 0,  0, gapz/2 ])*1.E-7
    if whichgap == 'y':
        def_centers[0,:] = np.array([ 0, -gapy/2, 0 ])*1.E-7
        def_centers[1,:] = np.array([ 0,  gapy/2, 0 ])*1.E-7

    def_orient[0] = angle1
    def_orient[1] = angle2

    def_all_radii[0, :] = np.array([longaxis1, shortaxis1])*1.E-7
    def_all_radii[1, :] = np.array([longaxis2, shortaxis2])*1.E-7
    return def_centers, def_orient, def_all_radii

def_centers, def_orients, def_all_radii = make_dimer_input(N=num,
                                                          shortaxis1=10,
                                                          longaxis1=30,
                                                          shortaxis2=10,
                                                          longaxis2=30, 
                                                          angle1=0, 
                                                          angle2=0,
                                                          gapy=0, 
                                                          gapz=(40+30)*2)

calc_dips = CalculateCrossSections(centers=def_centers, 
                                   orient=def_orients,
                                   all_radii=def_all_radii,
                                   num=num,
                                   n=1.00, 
                                   wp=8.959/hbar_eVs, 
                                   eps_inf=9.695, 
                                   gam_drude=0.073/hbar_eVs)


plot_analytics(which='abs', drive=np.array([0, 0, 1]), label='test')
plt.xlim([.5, 2.75])
plt.xlabel('Energy [eV]')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.ylabel('Abs. Cross-section [$\mu$m$^2$]')
plt.tight_layout()
plt.legend(frameon=False,loc='upper right')
plt.show()

# %% [markdown]
# ## Verify Against Simulation

# %%
def plot_simulation(filename, labelname, linetype):
    data = np.loadtxt(filename,skiprows=1)
    energy = data[:,0]
    ext_cross = data[:,1]
    abs_cross = data[:,2]
    sca_cross = data[:,3]
    plt.plot(energy, abs_cross, linetype, label=labelname)


name = str('../check_with_simulation/simulated_spectra/two_ellipsoids/Spectrum_bemret_homo_10_30_z40_polz')
plot_simulation(filename=name, linetype='', labelname='sim')

plot_analytics(which='abs', drive=np.array([0, 0, 1]), label='')

plt.xlim([0.5, 3.0])
plt.xlabel('Energy [eV]')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.ylabel('Abs. Cross-section [$\mu$m$^2$]')
plt.tight_layout()
plt.legend(frameon=False,loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-95c2519fcc75> in <module>
#       9
#      10 name = str('../check_with_simulation/simulated_spectra/two_ellipsoids/Spectrum_bemret_homo_10_30_z40_polz')
# ---> 11 plot_simulation(filename=name, linetype='', labelname='sim')
#      12
#      13 plot_analytics(which='abs', drive=np.array([0, 0, 1]), label='')
#
# <ipython-input-1-95c2519fcc75> in plot_simulation(filename, labelname, linetype)
#       1 def plot_simulation(filename, labelname, linetype):
# ----> 2     data = np.loadtxt(filename,skiprows=1)
#       3     energy = data[:,0]
#       4     ext_cross = data[:,1]
#       5     abs_cross = data[:,2]
#
# NameError: name 'np' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-cc585754b7f6> in <module>
#      56
#      57
# ---> 58 plot_analytics(drive=np.array([0, 0, 1]))
#
# <ipython-input-41-cc585754b7f6> in plot_analytics(drive)
#      42     Pabs = np.zeros((num, len(w)))
#      43     for i in range(0,len(w)):
# ---> 44         Pabs[:,i] = cross_sects(w=w[i], drive=drive)
#      45 #     if which == 'ext': P = Pext
#      46 #     if which == 'sca': P = Psca
#
# <ipython-input-41-cc585754b7f6> in cross_sects(w, drive)
#      28     for i in range(0, num):
#      29         # Evaluate the cross sections of each particle separately
# ---> 30         dip_params = calc_dips.DipoleParameters(centers, orient, all_radii, n, wp, eps_inf, gamNR_qs)
#      31 #         P_each[:,i] = P[3*i:3*(i+1), 0]
#      32 #         E_each[0,i] = dip_params.alpha(w=w, radius=self.all_radii[i, :],kind='short')**(-1)*P_each[0,i]
#
# AttributeError: 'CalculateCrossSections' object has no attribute 'DipoleParameters'
